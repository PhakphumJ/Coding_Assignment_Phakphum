# %% [markdown]
# # Using python to do silly stuff

# %% [markdown]
# ## Import CSV file

# %%
pwd
# Out:
# 'C:\\Users\\fphak\\Coding-assignment'

# %%
import pandas as pd
df = pd.read_csv(r'data\hotels-vienna.csv')

# %%
df
# Out:
#      country city_actual  rating_count center1label center2label  \
# 0    Austria      Vienna          36.0  City centre    Donauturm
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 423  Austria      Vienna           2.0  City centre    Donauturm
# 424  Austria      Vienna         145.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
# 427  Austria      Vienna          80.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...      offer_cat  year  \
# 0     17. Hernals     81  Vienna    4.0       4.5  ...   15-50% offer  2017
# 1     17. Hernals     81  Vienna    4.0       3.5  ...    1-15% offer  2017
# 2      Alsergrund     85  Vienna    4.0       3.5  ...   15-50% offer  2017
# 3      Alsergrund     83  Vienna    3.0       4.0  ...   15-50% offer  2017
# 4      Alsergrund     82  Vienna    4.0       3.5  ...   15-50% offer  2017
# ..            ...    ...     ...    ...       ...  ...            ...   ...
# 423        Wieden    109  Vienna    3.0       3.0  ...  50%-75% offer  2017
# 424        Wieden    185  Vienna    5.0       4.0  ...   15-50% offer  2017
# 425        Wieden    100  Vienna    4.0       4.5  ...    0% no offer  2017
# 426        Wieden     58  Vienna    3.0       3.0  ...   15-50% offer  2017
# 427        Wieden    110  Vienna    3.5       NaN  ...    1-15% offer  2017
#
#      month  weekend holiday  distance  distance_alter  accommodation_type  \
# 0       11        0       0       2.7             4.4           Apartment
# 1       11        0       0       1.7             3.8               Hotel
# 2       11        0       0       1.4             2.5               Hotel
# 3       11        0       0       1.7             2.5               Hotel
# 4       11        0       0       1.2             2.8               Hotel
# ..     ...      ...     ...       ...             ...                 ...
# 423     11        0       0       1.5             3.8           Apartment
# 424     11        0       0       0.8             3.6               Hotel
# 425     11        0       0       1.0             3.7               Hotel
# 426     11        0       0       1.4             4.1               Hotel
# 427     11        0       0       0.7             3.5           Apartment
#
#      nnights  rating
# 0          1     4.4
# 1          1     3.9
# 2          1     3.7
# 3          1     4.0
# 4          1     3.9
# ..       ...     ...
# 423        1     5.0
# 424        1     4.3
# 425        1     4.4
# 426        1     3.2
# 427        1     4.0
#
# [428 rows x 24 columns]

# %% [markdown]
# ## Outcome to demonstrate:

# %% [markdown]
# ### Aggregate data (average rating in each district).

# %%
df.groupby('neighbourhood')[['ratingta', 'rating']].agg("mean")
# Out:
#                       ratingta    rating
# neighbourhood
# 17. Hernals           4.000000  4.150000
# Alsergrund            3.700000  4.026667
# Donaustadt            4.062500  3.750000
# Favoriten             3.850000  3.470000
# Fischamend            2.500000  3.000000
# Graben                4.250000  4.333333
# Innere Stadt          4.217742  4.156522
# Josefstadt            3.869565  3.888000
# Kaerntner Strasse     4.312500  4.350000
# Landstrasse           3.978261  3.890323
# Leopoldstadt          4.057143  3.866667
# Margareten            4.055556  4.130769
# Mariahilf             4.027778  4.047826
# Neubau                4.093750  4.190000
# Ottakring             3.750000  3.740000
# Rudolfsheim-Funfhaus  3.933333  3.940000
# Schonbrunn            3.875000  3.921429
# Schwechat             3.714286  3.700000
# Vienna                3.859375  3.860976
# Voesendorf            3.250000  3.600000
# Wahring               3.625000  4.060000
# Wieden                3.947368  4.163636

# %% [markdown]
# ### Define and use functions (create dummy variables base on value of a column). ( #13)

# %%
def walkable_tocenter(d):
    if d['distance'] <= 1:
        return 'yes'
    else:
        return 'no'

# %%
df['walkable_tocenter'] = df.apply(walkable_tocenter, axis = 1)

# %%
def high_rating(d):
    if d['rating'] > 4:
        return 'yes'
    else:
        return 'no'

# %%
df['high_rating'] = df.apply(high_rating, axis = 1)

# %%
df
# Out:
#      country city_actual  rating_count center1label center2label  \
# 0    Austria      Vienna          36.0  City centre    Donauturm
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 423  Austria      Vienna           2.0  City centre    Donauturm
# 424  Austria      Vienna         145.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
# 427  Austria      Vienna          80.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...  month  weekend  \
# 0     17. Hernals     81  Vienna    4.0       4.5  ...     11        0
# 1     17. Hernals     81  Vienna    4.0       3.5  ...     11        0
# 2      Alsergrund     85  Vienna    4.0       3.5  ...     11        0
# 3      Alsergrund     83  Vienna    3.0       4.0  ...     11        0
# 4      Alsergrund     82  Vienna    4.0       3.5  ...     11        0
# ..            ...    ...     ...    ...       ...  ...    ...      ...
# 423        Wieden    109  Vienna    3.0       3.0  ...     11        0
# 424        Wieden    185  Vienna    5.0       4.0  ...     11        0
# 425        Wieden    100  Vienna    4.0       4.5  ...     11        0
# 426        Wieden     58  Vienna    3.0       3.0  ...     11        0
# 427        Wieden    110  Vienna    3.5       NaN  ...     11        0
#
#      holiday  distance distance_alter  accommodation_type  nnights  rating  \
# 0          0       2.7            4.4           Apartment        1     4.4
# 1          0       1.7            3.8               Hotel        1     3.9
# 2          0       1.4            2.5               Hotel        1     3.7
# 3          0       1.7            2.5               Hotel        1     4.0
# 4          0       1.2            2.8               Hotel        1     3.9
# ..       ...       ...            ...                 ...      ...     ...
# 423        0       1.5            3.8           Apartment        1     5.0
# 424        0       0.8            3.6               Hotel        1     4.3
# 425        0       1.0            3.7               Hotel        1     4.4
# 426        0       1.4            4.1               Hotel        1     3.2
# 427        0       0.7            3.5           Apartment        1     4.0
#
#      walkable_tocenter  high_rating
# 0                   no          yes
# 1                   no           no
# 2                   no           no
# 3                   no           no
# 4                   no           no
# ..                 ...          ...
# 423                 no          yes
# 424                yes          yes
# 425                yes          yes
# 426                 no           no
# 427                yes           no
#
# [428 rows x 26 columns]

# %% [markdown]
# ### Create a list of price of hotels in USD using for loop. Then merge it with the original dataframe. (Outcome #2, #3)

# %%
usd_price = []

for i in range(len(df)):
    price_in_usd = df['price'].iloc[i] * 1.05
    usd_price.append(price_in_usd)
    
usd_price
# Out:
# [85.05,
#  85.05,
#  89.25,
#  87.15,
#  86.10000000000001,
#  240.45000000000002,
#  108.15,
#  157.5,
#  84.0,
#  160.65,
#  63.0,
#  134.4,
#  105.0,
#  150.15,
#  111.30000000000001,
#  89.25,
#  80.85000000000001,
#  81.9,
#  81.9,
#  273.0,
#  165.9,
#  80.85000000000001,
#  80.85000000000001,
#  99.75,
#  163.8,
#  152.25,
#  218.4,
#  91.35000000000001,
#  137.55,
#  56.7,
#  145.95000000000002,
#  193.20000000000002,
#  133.35,
#  99.75,
#  103.95,
#  78.75,
#  79.8,
#  136.5,
#  95.55,
#  141.75,
#  58.800000000000004,
#  28.35,
#  92.4,
#  139.65,
#  34.65,
#  121.80000000000001,
#  74.55,
#  94.5,
#  88.2,
#  66.15,
#  61.95,
#  118.65,
#  228.9,
#  313.95,
#  163.8,
#  538.65,
#  139.65,
#  129.15,
#  229.95000000000002,
#  159.6,
#  120.75,
#  846.3000000000001,
#  144.9,
#  99.75,
#  153.3,
#  108.15,
#  131.25,
#  102.9,
#  127.05000000000001,
#  156.45000000000002,
#  126.0,
#  164.85,
#  274.05,
#  152.25,
#  288.75,
#  265.65000000000003,
#  219.45000000000002,
#  117.60000000000001,
#  144.9,
#  88.2,
#  208.95000000000002,
#  213.15,
#  121.80000000000001,
#  112.35000000000001,
#  133.35,
#  109.2,
#  176.4,
#  571.2,
#  264.6,
#  339.15000000000003,
#  165.9,
#  163.8,
#  228.9,
#  228.9,
#  141.75,
#  229.95000000000002,
#  187.95000000000002,
#  536.5500000000001,
#  164.85,
#  153.3,
#  210.0,
#  164.85,
#  144.9,
#  113.4,
#  304.5,
#  133.35,
#  119.7,
#  171.15,
#  121.80000000000001,
#  237.3,
#  242.55,
#  121.80000000000001,
#  79.8,
#  141.75,
#  193.20000000000002,
#  403.20000000000005,
#  174.3,
#  196.35,
#  389.55,
#  163.8,
#  231.0,
#  177.45000000000002,
#  108.15,
#  279.3,
#  137.55,
#  176.4,
#  106.05000000000001,
#  382.2,
#  254.10000000000002,
#  234.15,
#  156.45000000000002,
#  243.60000000000002,
#  119.7,
#  265.65000000000003,
#  171.15,
#  121.80000000000001,
#  145.95000000000002,
#  95.55,
#  82.95,
#  69.3,
#  105.0,
#  78.75,
#  76.65,
#  133.35,
#  115.5,
#  92.4,
#  61.95,
#  372.75,
#  61.95,
#  124.95,
#  159.6,
#  107.10000000000001,
#  381.15000000000003,
#  56.7,
#  106.05000000000001,
#  78.75,
#  76.65,
#  98.7,
#  67.2,
#  85.05,
#  170.1,
#  120.75,
#  106.05000000000001,
#  71.4,
#  371.7,
#  160.65,
#  212.10000000000002,
#  177.45000000000002,
#  191.1,
#  202.65,
#  144.9,
#  553.35,
#  149.1,
#  102.9,
#  115.5,
#  86.10000000000001,
#  95.55,
#  157.5,
#  87.15,
#  99.75,
#  137.55,
#  170.1,
#  185.85,
#  128.1,
#  82.95,
#  86.10000000000001,
#  86.10000000000001,
#  69.3,
#  177.45000000000002,
#  61.95,
#  114.45,
#  109.2,
#  152.25,
#  60.900000000000006,
#  112.35000000000001,
#  89.25,
#  193.20000000000002,
#  143.85,
#  121.80000000000001,
#  164.85,
#  115.5,
#  140.70000000000002,
#  82.95,
#  150.15,
#  138.6,
#  71.4,
#  134.4,
#  103.95,
#  156.45000000000002,
#  90.3,
#  162.75,
#  66.15,
#  164.85,
#  140.70000000000002,
#  148.05,
#  82.95,
#  144.9,
#  118.65,
#  179.55,
#  58.800000000000004,
#  88.2,
#  75.60000000000001,
#  616.35,
#  71.4,
#  107.10000000000001,
#  100.80000000000001,
#  85.05,
#  86.10000000000001,
#  69.3,
#  91.35000000000001,
#  382.2,
#  252.0,
#  118.65,
#  111.30000000000001,
#  93.45,
#  64.05,
#  96.60000000000001,
#  111.30000000000001,
#  105.0,
#  78.75,
#  88.2,
#  158.55,
#  91.35000000000001,
#  122.85000000000001,
#  126.0,
#  138.6,
#  71.4,
#  402.15000000000003,
#  168.0,
#  141.75,
#  116.55000000000001,
#  182.70000000000002,
#  66.15,
#  76.65,
#  105.0,
#  170.1,
#  90.3,
#  108.15,
#  70.35000000000001,
#  135.45000000000002,
#  84.0,
#  137.55,
#  157.5,
#  166.95000000000002,
#  90.3,
#  100.80000000000001,
#  137.55,
#  108.15,
#  89.25,
#  84.0,
#  97.65,
#  85.05,
#  80.85000000000001,
#  147.0,
#  103.95,
#  78.75,
#  110.25,
#  105.0,
#  93.45,
#  86.10000000000001,
#  86.10000000000001,
#  92.4,
#  157.5,
#  140.70000000000002,
#  91.35000000000001,
#  105.0,
#  88.2,
#  54.6,
#  102.9,
#  349.65000000000003,
#  103.95,
#  80.85000000000001,
#  168.0,
#  168.0,
#  79.8,
#  93.45,
#  118.65,
#  115.5,
#  193.20000000000002,
#  34.65,
#  1062.6000000000001,
#  103.95,
#  128.1,
#  128.1,
#  110.25,
#  102.9,
#  96.60000000000001,
#  114.45,
#  110.25,
#  139.65,
#  139.65,
#  54.6,
#  140.70000000000002,
#  84.0,
#  95.55,
#  135.45000000000002,
#  49.35,
#  73.5,
#  92.4,
#  142.8,
#  84.0,
#  137.55,
#  85.05,
#  139.65,
#  69.3,
#  80.85000000000001,
#  127.05000000000001,
#  72.45,
#  87.15,
#  55.650000000000006,
#  139.65,
#  80.85000000000001,
#  50.400000000000006,
#  149.1,
#  127.05000000000001,
#  71.4,
#  66.15,
#  106.05000000000001,
#  78.75,
#  163.8,
#  58.800000000000004,
#  86.10000000000001,
#  86.10000000000001,
#  111.30000000000001,
#  89.25,
#  87.15,
#  96.60000000000001,
#  177.45000000000002,
#  80.85000000000001,
#  96.60000000000001,
#  174.3,
#  143.85,
#  103.95,
#  147.0,
#  84.0,
#  95.55,
#  110.25,
#  136.5,
#  115.5,
#  122.85000000000001,
#  111.30000000000001,
#  69.3,
#  279.3,
#  60.900000000000006,
#  85.05,
#  114.45,
#  119.7,
#  131.25,
#  72.45,
#  72.45,
#  101.85000000000001,
#  77.7,
#  72.45,
#  87.15,
#  52.5,
#  136.5,
#  140.70000000000002,
#  140.70000000000002,
#  80.85000000000001,
#  107.10000000000001,
#  58.800000000000004,
#  194.25,
#  136.5,
#  81.9,
#  79.8,
#  71.4,
#  121.80000000000001,
#  180.6,
#  84.0,
#  91.35000000000001,
#  94.5,
#  105.0,
#  181.65,
#  96.60000000000001,
#  139.65,
#  140.70000000000002,
#  219.45000000000002,
#  69.3,
#  119.7,
#  93.45,
#  96.60000000000001,
#  88.2,
#  130.20000000000002,
#  194.25,
#  89.25,
#  139.65,
#  115.5,
#  90.3,
#  123.9,
#  132.3,
#  96.60000000000001,
#  206.85000000000002,
#  40.95,
#  141.75,
#  131.25,
#  70.35000000000001,
#  140.70000000000002,
#  95.55,
#  115.5,
#  88.2,
#  105.0,
#  99.75,
#  76.65,
#  114.45,
#  194.25,
#  105.0,
#  60.900000000000006,
#  115.5]

# %%
usd_price_df = pd.DataFrame(usd_price, columns =['price_in_usd'])
new_df = pd.concat([df, usd_price_df], axis=1)
new_df
# Out:
#      country city_actual  rating_count center1label center2label  \
# 0    Austria      Vienna          36.0  City centre    Donauturm
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 423  Austria      Vienna           2.0  City centre    Donauturm
# 424  Austria      Vienna         145.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
# 427  Austria      Vienna          80.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...  weekend  holiday  \
# 0     17. Hernals     81  Vienna    4.0       4.5  ...        0        0
# 1     17. Hernals     81  Vienna    4.0       3.5  ...        0        0
# 2      Alsergrund     85  Vienna    4.0       3.5  ...        0        0
# 3      Alsergrund     83  Vienna    3.0       4.0  ...        0        0
# 4      Alsergrund     82  Vienna    4.0       3.5  ...        0        0
# ..            ...    ...     ...    ...       ...  ...      ...      ...
# 423        Wieden    109  Vienna    3.0       3.0  ...        0        0
# 424        Wieden    185  Vienna    5.0       4.0  ...        0        0
# 425        Wieden    100  Vienna    4.0       4.5  ...        0        0
# 426        Wieden     58  Vienna    3.0       3.0  ...        0        0
# 427        Wieden    110  Vienna    3.5       NaN  ...        0        0
#
#      distance  distance_alter accommodation_type  nnights  rating  \
# 0         2.7             4.4          Apartment        1     4.4
# 1         1.7             3.8              Hotel        1     3.9
# 2         1.4             2.5              Hotel        1     3.7
# 3         1.7             2.5              Hotel        1     4.0
# 4         1.2             2.8              Hotel        1     3.9
# ..        ...             ...                ...      ...     ...
# 423       1.5             3.8          Apartment        1     5.0
# 424       0.8             3.6              Hotel        1     4.3
# 425       1.0             3.7              Hotel        1     4.4
# 426       1.4             4.1              Hotel        1     3.2
# 427       0.7             3.5          Apartment        1     4.0
#
#      walkable_tocenter  high_rating  price_in_usd
# 0                   no          yes         85.05
# 1                   no           no         85.05
# 2                   no           no         89.25
# 3                   no           no         87.15
# 4                   no           no         86.10
# ..                 ...          ...           ...
# 423                 no          yes        114.45
# 424                yes          yes        194.25
# 425                yes          yes        105.00
# 426                 no           no         60.90
# 427                yes           no        115.50
#
# [428 rows x 27 columns]
